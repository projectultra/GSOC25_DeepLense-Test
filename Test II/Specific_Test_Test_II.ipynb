npy
#   inflating: ./lens_dataset/__MACOSX/test_lenses/._103.npy
#   inflating: ./lens_dataset/test_lenses/16.npy
#   inflating: ./lens_dataset/__MACOSX/test_lenses/._16.npy
#   inflating: ./lens_dataset/test_lenses/17.npy
#   inflating: ./lens_dataset/__MACOSX/test_lenses/._17.npy
#   inflating: ./lens_dataset/test_lenses/102.npy
#   inflating: ./lens_dataset/__MACOSX/test_lenses/._102.npy
#   inflating: ./lens_dataset/test_lenses/116.npy
#   inflating: ./lens_dataset/__MACOSX/test_lenses/._116.npy
#   inflating: ./lens_dataset/test_lenses/112.npy
#   inflating: ./lens_dataset/__MACOSX/test_lenses/._112.npy
#   inflating: ./lens_dataset/test_lenses/106.npy
#   inflating: ./lens_dataset/__MACOSX/test_lenses/._106.npy
#   inflating: ./lens_dataset/test_lenses/13.npy
#   inflating: ./lens_dataset/__MACOSX/test_lenses/._13.npy
#   inflating: ./lens_dataset/test_lenses/12.npy
#   inflating: ./lens_dataset/__MACOSX/test_lenses/._12.npy
#   inflating: ./lens_dataset/test_lenses/107.npy
#   inflating: ./lens_dataset/__MACOSX/test_lenses/._107.npy
#   inflating: ./lens_dataset/test_lenses/113.npy
#   inflating: ./lens_dataset/__MACOSX/test_lenses/._113.npy
#   inflating: ./lens_dataset/test_lenses/139.npy
#   inflating: ./lens_dataset/__MACOSX/test_lenses/._139.npy
#   inflating: ./lens_dataset/test_lenses/105.npy
#   inflating: ./lens_dataset/__MACOSX/test_lenses/._105.npy
#   inflating: ./lens_dataset/test_lenses/111.npy
#   inflating: ./lens_dataset/__MACOSX/test_lenses/._111.npy
#   inflating: ./lens_dataset/test_lenses/10.npy
#   inflating: ./lens_dataset/__MACOSX/test_lenses/._10.npy
#   inflating: ./lens_dataset/test_lenses/38.npy
#   inflating: ./lens_dataset/__MACOSX/test_lenses/._38.npy
#   inflating: ./lens_dataset/test_lenses/39.npy
#   inflating: ./lens_dataset/__MACOSX/test_lenses/._39.npy
#   inflating: ./lens_dataset/test_lenses/11.npy
#   inflating: ./lens_dataset/__MACOSX/test_lenses/._11.npy
#   inflating: ./lens_dataset/test_lenses/110.npy
#   inflating: ./lens_dataset/__MACOSX/test_lenses/._110.npy
#   inflating: ./lens_dataset/test_lenses/104.npy
#   inflating: ./lens_dataset/__MACOSX/test_lenses/._104.npy
#   inflating: ./lens_dataset/test_lenses/138.npy
#   inflating: ./lens_dataset/__MACOSX/test_lenses/._138.npy

# %% [markdown]
# ## Image Dataset Loading

# %% [markdown]
# The dataset is highly imbalanced, with much fewer lens images. To address this, I apply oversampling using data augmentation.
#
# **Augmentations applied:**
# - Vertical flip
# - Horizontal flip
# - Combined vertical & horizontal flip
# - 90° rotation
# - 270° rotation

# %%
import os
import torch
import numpy as np
from torch.utils.data import Dataset, DataLoader, SubsetRandomSampler

# Check for CUDA
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Custom Dataset Class with Flipping Augmentation for Lenses
class LensingDataset(Dataset):
    def __init__(self, data_dir, data_type="train", transform=None):
        self.data_dir = data_dir
        self.transform = transform
        self.data = []
        self.labels = []

        # Mapping based on data_type (train or test)
        mapping = {
            f"{data_type}_nonlenses": 0,
            f"{data_type}_lenses": 1
        }

        for class_name, label in mapping.items():
            class_dir = os.path.join(data_dir, class_name)
            if not os.path.exists(class_dir):
                print(f"Warning: Directory {class_dir} not found, skipping.")
                continue
            for img_file in os.listdir(class_dir):
                img_path = os.path.join(class_dir, img_file)
                img = np.load(img_path)

                # Add the original image
                self.data.append(img)
                self.labels.append(label)

                # If this is a "lenses" image (label 1), add augmented versions
                if label == 1 and data_type == 'train':
                    # Vertical flip (flip along the height axis)
                    img_vflip = np.fliplr(img).copy()
                    self.data.append(img_vflip)
                    self.labels.append(label)

                    # Horizontal flip (flip along the width axis)
                    img_hflip = np.flipud(img).copy()
                    self.data.append(img_hflip)
                    self.labels.append(label)

                    img_mflip = np.flipud(np.fliplr(img)).copy()
                    self.data.append(img_mflip)
                    self.labels.append(label)

                    # 2. Rotation Augmentations (90°, 270°)
                    img_rot90 = np.rot90(img, k=1, axes=(1, 2)).copy()  # 90° clockwise
                    self.data.append(img_rot90)
                    self.labels.append(label)

                    img_rot270 = np.rot90(img, k=3, axes=(1, 2)).copy()  # 270° clockwise
                    self.data.append(img_rot270)
                    self.labels.append(label)

        if len(self.data) == 0:
            raise ValueError(f"No data found for {data_type} in {data_dir}, check folder structure.")

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img = self.data[idx]
        label = self.labels[idx]
        img = torch.tensor(img, dtype=torch.float32)
        img = img.to(device)
        label = torch.tensor(label, dtype=torch.long).to(device)
        label = label.to(device)
        return img, label

# %% [markdown]
# The dataset is structured into train and test folders. The train set is further split into 90% training and 10% validation to evaluate model performance before testing. This ensures proper generalization assessment and prevents overfitting.

# %%
# Load and split
data_path = "./lens_dataset"
full_train_dataset = LensingDataset(data_path, data_type="train")
test_dataset = LensingDataset(data_path, data_type="test")

# Simple random split for train/val
n_train = int(len(full_train_dataset) * 0.9)  # 90% train
indices = torch.randperm(len(full_train_dataset)).tolist()
train_sampler = SubsetRandomSampler(indices[:n_train])
val_sampler = SubsetRandomSampler(indices[n_train:])

# DataLoaders
train_loader = DataLoader(full_train_dataset, batch_size=32, sampler=train_sampler)
val_loader = DataLoader(full_train_dataset, batch_size=128, sampler=val_sampler)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)

# Verify sizes
print(f"Train size: {len(train_sampler)}")
print(f"Val size: {len(val_sampler)}")
print(f"Test size: {len(test_dataset)}")

# Optional: Print class distribution to verify augmentation
train_labels = [full_train_dataset.labels[i] for i in indices[:n_train]]
val_labels = [full_train_dataset.labels[i] for i in indices[n_train:]]
test_labels = test_dataset.labels

print(f"Train class distribution: {np.bincount(train_labels)}")
print(f"Val class distribution: {np.bincount(val_labels)}")
print(f"Test class distribution: {np.bincount(test_labels)}")
# Out:
# Train size: 35149
# Val size: 3906
# Test size: 19650
# Train class distribution: [25748  9401]
# Val class distribution: [2927  979]
# Test class distribution: [19455   195]

# %% [markdown]
# ## Model Architecture

# %% [markdown]
# The CNN model has three main parts:
#
# 1. **Stem Layer**: A `16 Channel` Conv2D (`3x3 Filter, stride=2`), BatchNorm, PReLU.
# 2. **Feature Extraction**: Two **Basic CNN Blocks** (`16→32, 32→64`), where I opted to use **Depthwise Separable Convolutions** for efficiency, followed by BatchNorm, PReLU, and Dropout (0.5).
# 3. **Classification Head**: A `1x1` Conv layer (`64→128`), followed by Adaptive Average Pooling. The output is pooled along the channel dimension, then passed through Dropout (`0.3`) and fully connected layers (`128→32→2`) for classification. <br>
#
#
# **Other Features**
# Dropout: Applied at different stages to reduce overfitting.
#
# PReLU: Used instead of ReLU for better performance adaptability.

# %%
import torch.optim as optim
import torch.nn as nn
import torch
from torch.utils.data import DataLoader
import torch.nn.functional as F

class BasicBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride):
        super(BasicBlock, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, in_channels, kernel_size=3, stride=stride, padding=1, groups=in_channels, bias=False),
            nn.BatchNorm2d(in_channels),
            nn.PReLU(in_channels),
            nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False),
            nn.BatchNorm2d(out_channels),
        )
        self.prelu = nn.PReLU(out_channels)
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x = self.conv(x)
        x = self.prelu(x)
        x = self.dropout(x)
        return x

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.stem = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(16),
            nn.PReLU(16)
        )
        self.features = nn.Sequential(
            BasicBlock(16, 32, stride=2),
            BasicBlock(32, 64, stride=2),
        )
        self.head = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=1, bias=False),
            nn.BatchNorm2d(128),
            nn.PReLU(128),
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Dropout(0.3),
            nn.Linear(128, 32),
            nn.Linear(32, 2)
        )

    def forward(self, x):
        x = self.stem(x)
        x = self.features(x)
        x = self.head(x)
        return x

# %% [markdown]
# ## Model Training

# %% [markdown]
# To handle class imbalance, I used Focal Loss, which helps the model focus on hard samples by reducing the impact of easy examples.<br><br>
# Alpha (α = 4.0): Balances class importance. Higher values give more weight to the minority class.<br>
# Gamma (γ = 3.0): Controls focus on hard samples. Higher values down-weight easy samples more aggressively.

# %%
def focal_loss(outputs, labels, alpha=4.0, gamma=3.0):
    ce_loss = F.cross_entropy(outputs, labels, reduction='none')
    pt = torch.exp(-ce_loss)
    focal_loss = alpha * (1 - pt) ** gamma * ce_loss
    return focal_loss

# %% [markdown]
# The training pipeline uses **Adam** (`lr=0.001`) as the optimiser. It tracks training and validation loss, accuracy, precision, recall, and F1-score, ensuring detailed performance evaluation.<br>
#
# **Early stopping** is implemented to prevent overfitting by monitoring validation loss and stopping training if no improvement is observed for **20 consecutive epochs** (patience). <br>
#
# The best model weights are saved based on the lowest validation loss. Finally, the trained model is stored as `best_model.pth`.

# %%
import torch.optim as optim
import torch.nn as nn
import torch
from sklearn.metrics import precision_recall_fscore_support
import copy

def train_model(model, train_loader, val_loader, criterion, optimizer, epochs=30, device='cuda',
                patience=5, min_delta=0.001):
    model.to(device)

    # Early stopping variables
    best_val_loss = float('inf')
    best_model_weights = copy.deepcopy(model.state_dict())
    early_stop_counter = 0

    for epoch in range(epochs):
        # Training phase
        model.train()
        total_train_loss = 0.0
        train_preds = []
        train_labels = []

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            train_preds.extend(predicted.cpu().numpy())
            train_labels.extend(labels.cpu().numpy())

        train_loss = total_train_loss / len(train_loader)

        # Calculate training metrics
        train_prec, train_rec, train_f1, _ = precision_recall_fscore_support(
            train_labels, train_preds, average='weighted', zero_division=0
        )
        train_acc = sum(p == l for p, l in zip(train_preds, train_labels)) / len(train_labels)

        # Validation phase
        model.eval()
        total_val_loss = 0.0
        val_preds = []
        val_labels = []

        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                total_val_loss += loss.item()

                _, predicted = torch.max(outputs, 1)
                val_preds.extend(predicted.cpu().numpy())
                val_labels.extend(labels.cpu().numpy())

        val_loss = total_val_loss / len(val_loader)

        # Calculate validation metrics
        val_prec, val_rec, val_f1, _ = precision_recall_fscore_support(
            val_labels, val_preds, average='weighted', zero_division=0
        )
        val_acc = sum(p == l for p, l in zip(val_preds, val_labels)) / len(val_labels)

        # Calculate per-class metrics for validation
        per_class_metrics = precision_recall_fscore_support(
            val_labels, val_preds, average=None, zero_division=0
        )

        # Print detailed metrics
        print(f"\nEpoch {epoch+1}/{epochs}")
        print(f"Train - Loss: {train_loss:.4f}, Acc: {train_acc:.4f}")
        print(f"Val   - Loss: {val_loss:.4f}, Acc: {val_acc:.4f}")
        print(f"Class 1 - Prec: {per_class_metrics[0][1]:.4f}, "
              f"Rec: {per_class_metrics[1][1]:.4f}, F1: {per_class_metrics[2][1]:.4f}")


        # Early stopping and best model saving
        if val_loss < best_val_loss - min_delta:
            best_val_loss = val_loss
            best_model_weights = copy.deepcopy(model.state_dict())
            early_stop_counter = 0
            print(f"New best model saved with val_loss: {best_val_loss:.4f}")
        else:
            early_stop_counter += 1
            print(f"Early stopping counter: {early_stop_counter}/{patience}")

        if early_stop_counter >= patience:
            print("Early stopping triggered!")
            break

    # Load best weights
    model.load_state_dict(best_model_weights)
    print(f"Training completed. Best validation loss: {best_val_loss:.4f}")
    return model

model = CNNModel().to('cuda')

criterion  = focal_loss

optimizer = optim.Adam(model.parameters(), lr=0.001)

# Train with LR annealing and early stopping
trained_model = train_model(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    epochs=100,
    device='cuda',
    patience=20,  # Stop if no improvement for 5 epochs
    min_delta=0.0001  # Minimum improvement required
)

torch.save(trained_model.state_dict(), 'Test_II_Model.pth')
# Out:
# Epoch 1/100
# Train - Loss: 44.2328, Acc: 0.8406
# Val   - Loss: 138.1152, Acc: 0.8789
# Class 1 - Prec: 0.7196, Rec: 0.8468, F1: 0.7780
# New best model saved with val_loss: 138.1152
#
# Epoch 2/100
# Train - Loss: 34.5847, Acc: 0.8868
# Val   - Loss: 122.7977, Acc: 0.9063
# Class 1 - Prec: 0.7739, Rec: 0.8846, F1: 0.8255
# New best model saved with val_loss: 122.7977
#
# Epoch 3/100
# Train - Loss: 30.5803, Acc: 0.9043
# Val   - Loss: 106.0034, Acc: 0.9219
# Class 1 - Prec: 0.8317, Rec: 0.8631, F1: 0.8471
# New best model saved with val_loss: 106.0034
#
# Epoch 4/100
# Train - Loss: 28.5601, Acc: 0.9101
# Val   - Loss: 97.4947, Acc: 0.9237
# Class 1 - Prec: 0.8485, Rec: 0.8468, F1: 0.8476
# New best model saved with val_loss: 97.4947
#
# Epoch 5/100
# Train - Loss: 26.6376, Acc: 0.9169
# Val   - Loss: 95.4101, Acc: 0.9240
# Class 1 - Prec: 0.9220, Rec: 0.7610, F1: 0.8338
# New best model saved with val_loss: 95.4101
#
# Epoch 6/100
# Train - Loss: 26.0224, Acc: 0.9178
# Val   - Loss: 93.4997, Acc: 0.9286
# Class 1 - Prec: 0.8365, Rec: 0.8887, F1: 0.8618
# New best model saved with val_loss: 93.4997
#
# Epoch 7/100
# Train - Loss: 25.1540, Acc: 0.9224
# Val   - Loss: 86.6322, Acc: 0.9355
# Class 1 - Prec: 0.8721, Rec: 0.8703, F1: 0.8712
# New best model saved with val_loss: 86.6322
#
# Epoch 8/100
# Train - Loss: 24.5783, Acc: 0.9244
# Val   - Loss: 89.0755, Acc: 0.9352
# Class 1 - Prec: 0.8484, Rec: 0.9030, F1: 0.8748
# Early stopping counter: 1/20
#
# Epoch 9/100
# Train - Loss: 24.0345, Acc: 0.9243
# Val   - Loss: 84.7821, Acc: 0.9327
# Class 1 - Prec: 0.8817, Rec: 0.8447, F1: 0.8628
# New best model saved with val_loss: 84.7821
#
# Epoch 10/100
# Train - Loss: 23.1846, Acc: 0.9279
# Val   - Loss: 84.1209, Acc: 0.9357
# Class 1 - Prec: 0.8576, Rec: 0.8917, F1: 0.8743
# New best model saved with val_loss: 84.1209
#
# Epoch 11/100
# Train - Loss: 22.8973, Acc: 0.9289
# Val   - Loss: 82.1554, Acc: 0.9350
# Class 1 - Prec: 0.9200, Rec: 0.8110, F1: 0.8621
# New best model saved with val_loss: 82.1554
#
# Epoch 12/100
# Train - Loss: 22.5539, Acc: 0.9298
# Val   - Loss: 77.9638, Acc: 0.9383
# Class 1 - Prec: 0.9128, Rec: 0.8335, F1: 0.8713
# New best model saved with val_loss: 77.9638
#
# Epoch 13/100
# Train - Loss: 21.4456, Acc: 0.9325
# Val   - Loss: 77.0823, Acc: 0.9403
# Class 1 - Prec: 0.9126, Rec: 0.8427, F1: 0.8763
# New best model saved with val_loss: 77.0823
#
# Epoch 14/100
# Train - Loss: 21.7965, Acc: 0.9326
# Val   - Loss: 77.1348, Acc: 0.9424
# Class 1 - Prec: 0.8808, Rec: 0.8907, F1: 0.8857
# Early stopping counter: 1/20
#
# Epoch 15/100
# Train - Loss: 21.6250, Acc: 0.9325
# Val   - Loss: 76.3072, Acc: 0.9403
# Class 1 - Prec: 0.9028, Rec: 0.8539, F1: 0.8777
# New best model saved with val_loss: 76.3072
#
# Epoch 16/100
# Train - Loss: 21.4446, Acc: 0.9336
# Val   - Loss: 76.0081, Acc: 0.9411
# Class 1 - Prec: 0.9175, Rec: 0.8407, F1: 0.8774
# New best model saved with val_loss: 76.0081
#
# Epoch 17/100
# Train - Loss: 21.2003, Acc: 0.9340
# Val   - Loss: 83.7363, Acc: 0.9342
# Class 1 - Prec: 0.8498, Rec: 0.8958, F1: 0.8722
# Early stopping counter: 1/20
#
# Epoch 18/100
# Train - Loss: 20.5458, Acc: 0.9352
# Val   - Loss: 71.7633, Acc: 0.9437
# Class 1 - Prec: 0.8966, Rec: 0.8764, F1: 0.8864
# New best model saved with val_loss: 71.7633
#
# Epoch 19/100
# Train - Loss: 20.6808, Acc: 0.9359
# Val   - Loss: 75.6542, Acc: 0.9437
# Class 1 - Prec: 0.9094, Rec: 0.8611, F1: 0.8846
# Early stopping counter: 1/20
#
# Epoch 20/100
# Train - Loss: 20.2083, Acc: 0.9360
# Val   - Loss: 77.3610, Acc: 0.9375
# Class 1 - Prec: 0.9422, Rec: 0.7998, F1: 0.8652
# Early stopping counter: 2/20
#
# Epoch 21/100
# Train - Loss: 20.0207, Acc: 0.9382
# Val   - Loss: 70.6433, Acc: 0.9447
# Class 1 - Prec: 0.9197, Rec: 0.8539, F1: 0.8856
# New best model saved with val_loss: 70.6433
#
# Epoch 22/100
# Train - Loss: 19.9982, Acc: 0.9371
# Val   - Loss: 72.1836, Acc: 0.9470
# Class 1 - Prec: 0.9063, Rec: 0.8795, F1: 0.8927
# Early stopping counter: 1/20
#
# Epoch 23/100
# Train - Loss: 19.4954, Acc: 0.9385
# Val   - Loss: 67.9710, Acc: 0.9462
# Class 1 - Prec: 0.9060, Rec: 0.8764, F1: 0.8910
# New best model saved with val_loss: 67.9710
#
# Epoch 24/100
# Train - Loss: 19.4332, Acc: 0.9391
# Val   - Loss: 70.4077, Acc: 0.9450
# Class 1 - Prec: 0.8963, Rec: 0.8825, F1: 0.8893
# Early stopping counter: 1/20
#
# Epoch 25/100
# Train - Loss: 18.9287, Acc: 0.9405
# Val   - Loss: 72.7448, Acc: 0.9462
# Class 1 - Prec: 0.8936, Rec: 0.8917, F1: 0.8926
# Early stopping counter: 2/20
#
# Epoch 26/100
# Train - Loss: 19.1372, Acc: 0.9405
# Val   - Loss: 76.9415, Acc: 0.9416
# Class 1 - Prec: 0.8836, Rec: 0.8836, F1: 0.8836
# Early stopping counter: 3/20
#
# Epoch 27/100
# Train - Loss: 18.8071, Acc: 0.9406
# Val   - Loss: 74.6739, Acc: 0.9421
# Class 1 - Prec: 0.9303, Rec: 0.8315, F1: 0.8781
# Early stopping counter: 4/20
#
# Epoch 28/100
# Train - Loss: 18.8536, Acc: 0.9418
# Val   - Loss: 68.7973, Acc: 0.9470
# Class 1 - Prec: 0.9168, Rec: 0.8672, F1: 0.8913
# Early stopping counter: 5/20
#
# Epoch 29/100
# Train - Loss: 18.9311, Acc: 0.9397
# Val   - Loss: 68.8517, Acc: 0.9467
# Class 1 - Prec: 0.9003, Rec: 0.8856, F1: 0.8929
# Early stopping counter: 6/20
#
# Epoch 30/100
# Train - Loss: 18.4675, Acc: 0.9424
# Val   - Loss: 70.3611, Acc: 0.9483
# Class 1 - Prec: 0.9120, Rec: 0.8784, F1: 0.8949
# Early stopping counter: 7/20
#
# Epoch 31/100
# Train - Loss: 18.3994, Acc: 0.9424
# Val   - Loss: 68.8706, Acc: 0.9470
# Class 1 - Prec: 0.9376, Rec: 0.8447, F1: 0.8888
# Early stopping counter: 8/20
#
# Epoch 32/100
# Train - Loss: 18.5742, Acc: 0.9416
# Val   - Loss: 67.8477, Acc: 0.9501
# Class 1 - Prec: 0.9058, Rec: 0.8938, F1: 0.8997
# New best model saved with val_loss: 67.8477
#
# Epoch 33/100
# Train - Loss: 18.0707, Acc: 0.9419
# Val   - Loss: 69.6618, Acc: 0.9475
# Class 1 - Prec: 0.8886, Rec: 0.9040, F1: 0.8962
# Early stopping counter: 1/20
#
# Epoch 34/100
# Train - Loss: 18.1612, Acc: 0.9430
# Val   - Loss: 73.0090, Acc: 0.9444
# Class 1 - Prec: 0.9504, Rec: 0.8212, F1: 0.8811
# Early stopping counter: 2/20
#
# Epoch 35/100
# Train - Loss: 17.7408, Acc: 0.9432
# Val   - Loss: 67.1117, Acc: 0.9501
# Class 1 - Prec: 0.9118, Rec: 0.8866, F1: 0.8990
# New best model saved with val_loss: 67.1117
#
# Epoch 36/100
# Train - Loss: 17.7282, Acc: 0.9444
# Val   - Loss: 68.3208, Acc: 0.9475
# Class 1 - Prec: 0.9358, Rec: 0.8488, F1: 0.8902
# Early stopping counter: 1/20
#
# Epoch 37/100
# Train - Loss: 17.8924, Acc: 0.9438
# Val   - Loss: 65.9098, Acc: 0.9519
# Class 1 - Prec: 0.9221, Rec: 0.8825, F1: 0.9019
# New best model saved with val_loss: 65.9098
#
# Epoch 38/100
# Train - Loss: 17.8333, Acc: 0.9447
# Val   - Loss: 69.8636, Acc: 0.9465
# Class 1 - Prec: 0.9306, Rec: 0.8498, F1: 0.8884
# Early stopping counter: 1/20
#
# Epoch 39/100
# Train - Loss: 17.7287, Acc: 0.9436
# Val   - Loss: 65.5629, Acc: 0.9506
# Class 1 - Prec: 0.9338, Rec: 0.8641, F1: 0.8976
# New best model saved with val_loss: 65.5629
#
# Epoch 40/100
# Train - Loss: 17.7855, Acc: 0.9442
# Val   - Loss: 68.4684, Acc: 0.9498
# Class 1 - Prec: 0.9082, Rec: 0.8897, F1: 0.8989
# Early stopping counter: 1/20
#
# Epoch 41/100
# Train - Loss: 17.6910, Acc: 0.9444
# Val   - Loss: 65.8805, Acc: 0.9498
# Class 1 - Prec: 0.9169, Rec: 0.8795, F1: 0.8978
# Early stopping counter: 2/20
#
# Epoch 42/100
# Train - Loss: 17.4939, Acc: 0.9456
# Val   - Loss: 65.4232, Acc: 0.9506
# Class 1 - Prec: 0.9217, Rec: 0.8774, F1: 0.8990
# New best model saved with val_loss: 65.4232
#
# Epoch 43/100
# Train - Loss: 16.9585, Acc: 0.9459
# Val   - Loss: 69.9049, Acc: 0.9467
# Class 1 - Prec: 0.9376, Rec: 0.8437, F1: 0.8882
# Early stopping counter: 1/20
#
# Epoch 44/100
# Train - Loss: 17.5230, Acc: 0.9451
# Val   - Loss: 65.7373, Acc: 0.9508
# Class 1 - Prec: 0.9236, Rec: 0.8764, F1: 0.8994
# Early stopping counter: 2/20
#
# Epoch 45/100
# Train - Loss: 17.5683, Acc: 0.9443
# Val   - Loss: 67.5857, Acc: 0.9508
# Class 1 - Prec: 0.9044, Rec: 0.8989, F1: 0.9016
# Early stopping counter: 3/20
#
# Epoch 46/100
# Train - Loss: 17.2143, Acc: 0.9458
# Val   - Loss: 67.1171, Acc: 0.9508
# Class 1 - Prec: 0.8987, Rec: 0.9060, F1: 0.9023
# Early stopping counter: 4/20
#
# Epoch 47/100
# Train - Loss: 17.0483, Acc: 0.9465
# Val   - Loss: 64.2408, Acc: 0.9506
# Class 1 - Prec: 0.9244, Rec: 0.8744, F1: 0.8987
# New best model saved with val_loss: 64.2408
#
# Epoch 48/100
# Train - Loss: 17.0650, Acc: 0.9446
# Val   - Loss: 69.0257, Acc: 0.9452
# Class 1 - Prec: 0.9392, Rec: 0.8355, F1: 0.8843
# Early stopping counter: 1/20
#
# Epoch 49/100
# Train - Loss: 17.4714, Acc: 0.9437
# Val   - Loss: 64.3725, Acc: 0.9526
# Class 1 - Prec: 0.9144, Rec: 0.8948, F1: 0.9045
# Early stopping counter: 2/20
#
# Epoch 50/100
# Train - Loss: 16.9745, Acc: 0.9481
# Val   - Loss: 63.3771, Acc: 0.9542
# Class 1 - Prec: 0.9211, Rec: 0.8938, F1: 0.9072
# New best model saved with val_loss: 63.3771
#
# Epoch 51/100
# Train - Loss: 16.9415, Acc: 0.9474
# Val   - Loss: 64.3522, Acc: 0.9521
# Class 1 - Prec: 0.9151, Rec: 0.8917, F1: 0.9033
# Early stopping counter: 1/20
#
# Epoch 52/100
# Train - Loss: 17.0959, Acc: 0.9450
# Val   - Loss: 67.8327, Acc: 0.9467
# Class 1 - Prec: 0.9519, Rec: 0.8294, F1: 0.8865
# Early stopping counter: 2/20
#
# Epoch 53/100
# Train - Loss: 16.6970, Acc: 0.9465
# Val   - Loss: 67.4317, Acc: 0.9501
# Class 1 - Prec: 0.9365, Rec: 0.8590, F1: 0.8961
# Early stopping counter: 3/20
#
# Epoch 54/100
# Train - Loss: 16.7599, Acc: 0.9467
# Val   - Loss: 70.3232, Acc: 0.9455
# Class 1 - Prec: 0.8770, Rec: 0.9101, F1: 0.8932
# Early stopping counter: 4/20
#
# Epoch 55/100
# Train - Loss: 16.8430, Acc: 0.9470
# Val   - Loss: 69.8638, Acc: 0.9465
# Class 1 - Prec: 0.9446, Rec: 0.8355, F1: 0.8867
# Early stopping counter: 5/20
#
# Epoch 56/100
# Train - Loss: 16.7239, Acc: 0.9471
# Val   - Loss: 66.0721, Acc: 0.9503
# Class 1 - Prec: 0.9009, Rec: 0.9009, F1: 0.9009
# Early stopping counter: 6/20
#
# Epoch 57/100
# Train - Loss: 16.8422, Acc: 0.9465
# Val   - Loss: 67.5300, Acc: 0.9475
# Class 1 - Prec: 0.9281, Rec: 0.8570, F1: 0.8911
# Early stopping counter: 7/20
#
# Epoch 58/100
# Train - Loss: 16.4585, Acc: 0.9465
# Val   - Loss: 64.2851, Acc: 0.9524
# Class 1 - Prec: 0.9178, Rec: 0.8897, F1: 0.9035
# Early stopping counter: 8/20
#
# Epoch 59/100
# Train - Loss: 16.8226, Acc: 0.9473
# Val   - Loss: 66.9365, Acc: 0.9485
# Class 1 - Prec: 0.9192, Rec: 0.8713, F1: 0.8946
# Early stopping counter: 9/20
#
# Epoch 60/100
# Train - Loss: 16.5794, Acc: 0.9461
# Val   - Loss: 72.7101, Acc: 0.9493
# Class 1 - Prec: 0.9240, Rec: 0.8693, F1: 0.8958
# Early stopping counter: 10/20
#
# Epoch 61/100
# Train - Loss: 16.6890, Acc: 0.9466
# Val   - Loss: 63.7986, Acc: 0.9529
# Class 1 - Prec: 0.9102, Rec: 0.9009, F1: 0.9055
# Early stopping counter: 11/20
#
# Epoch 62/100
# Train - Loss: 16.5422, Acc: 0.9473
# Val   - Loss: 66.5236, Acc: 0.9508
# Class 1 - Prec: 0.9367, Rec: 0.8621, F1: 0.8979
# Early stopping counter: 12/20
#
# Epoch 63/100
# Train - Loss: 16.6933, Acc: 0.9461
# Val   - Loss: 69.4669, Acc: 0.9480
# Class 1 - Prec: 0.9264, Rec: 0.8611, F1: 0.8925
# Early stopping counter: 13/20
#
# Epoch 64/100
# Train - Loss: 16.7486, Acc: 0.9461
# Val   - Loss: 66.8047, Acc: 0.9496
# Class 1 - Prec: 0.9393, Rec: 0.8539, F1: 0.8946
# Early stopping counter: 14/20
#
# Epoch 65/100
# Train - Loss: 16.5779, Acc: 0.9471
# Val   - Loss: 63.6898, Acc: 0.9496
# Class 1 - Prec: 0.9133, Rec: 0.8825, F1: 0.8977
# Early stopping counter: 15/20
#
# Epoch 66/100
# Train - Loss: 16.4625, Acc: 0.9476
# Val   - Loss: 67.6731, Acc: 0.9470
# Class 1 - Prec: 0.9298, Rec: 0.8529, F1: 0.8897
# Early stopping counter: 16/20
#
# Epoch 67/100
# Train - Loss: 16.5099, Acc: 0.9466
# Val   - Loss: 72.6470, Acc: 0.9460
# Class 1 - Prec: 0.9496, Rec: 0.8284, F1: 0.8849
# Early stopping counter: 17/20
#
# Epoch 68/100
# Train - Loss: 16.3182, Acc: 0.9482
# Val   - Loss: 65.1509, Acc: 0.9478
# Class 1 - Prec: 0.8950, Rec: 0.8968, F1: 0.8959
# Early stopping counter: 18/20
#
# Epoch 69/100
# Train - Loss: 16.6447, Acc: 0.9458
# Val   - Loss: 68.0409, Acc: 0.9488
# Class 1 - Prec: 0.9588, Rec: 0.8315, F1: 0.8906
# Early stopping counter: 19/20
#
# Epoch 70/100
# Train - Loss: 16.4774, Acc: 0.9482
# Val   - Loss: 66.6321, Acc: 0.9506
# Class 1 - Prec: 0.9077, Rec: 0.8938, F1: 0.9007
# Early stopping counter: 20/20
# Early stopping triggered!
# Training completed. Best validation loss: 63.3771

# %% [markdown]
# ## Model Evaluation

# %%
import numpy as np
import plotly.graph_objs as go
import plotly.figure_factory as ff
from sklearn.metrics import roc_curve, auc
import torch

def plot_roc_curve(y_true, y_pred_proba):
    """
    Plot ROC curve and calculate AUC score using Plotly

    Parameters:
    y_true (array-like): True binary labels
    y_pred_proba (array-like): Predicted probabilities for positive class

    Returns:
    plotly Figure object
    """
    # Compute ROC curve and ROC area
    fpr, tpr, _ = roc_curve(y_true, y_pred_proba)
    roc_auc = auc(fpr, tpr)

    # Create Plotly figure
    fig = go.Figure()

    # ROC Curve
    fig.add_trace(go.Scatter(
        x=fpr,
        y=tpr,
        mode='lines',
        name=f'ROC Curve (AUC = {roc_auc:.2f})',
        line=dict(color='darkorange', width=2)
    ))

    # Diagonal line
    fig.add_trace(go.Scatter(
        x=[0, 1],
        y=[0, 1],
        mode='lines',
        name='Random Classifier',
        line=dict(color='navy', dash='dash')
    ))

    # Update layout
    fig.update_layout(
        title='Receiver Operating Characteristic (ROC) Curve',
        xaxis_title='False Positive Rate',
        yaxis_title='True Positive Rate',
        width=800,
        height=600
    )

    return fig

# Example usage function
def evaluate_model(model, test_loader, device):
    """
    Evaluate model and generate visualizations

    Parameters:
    model (torch.nn.Module): Trained PyTorch model
    test_loader (DataLoader): Test data loader
    device (torch.device): Computing device

    Returns:
    Tuple of ROC curve figure, Confusion matrix figure, and metrics
    """
    model.eval()
    y_true, y_pred_proba, y_pred = [], [], []

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = torch.sigmoid(model(images))
            y_true.extend(labels.cpu().numpy())
            y_pred_proba.extend(outputs.cpu().numpy())
            y_pred.extend((outputs > 0.5).int().cpu().numpy())

    # Convert to numpy arrays
    y_true = np.array(y_true)
    y_pred_proba = np.array(y_pred_proba)[:, 1]
    y_pred = np.array(y_pred)[:,1]

    # Generate plots
    roc_fig = plot_roc_curve(y_true, y_pred_proba)

    return roc_fig, {
        'AUC': auc(*(roc_curve(y_true, y_pred_proba)[:2])),
        'Accuracy': np.mean(y_true == y_pred)
    }

roc_figure, metrics = evaluate_model(model, test_loader, device)
print(metrics)
roc_figure.show()
# Out:
# {'AUC': 0.9628338901739056, 'Accuracy': 0.9721628498727736}
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="52a3a471-6383-4c71-8016-53316b228fcd" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("